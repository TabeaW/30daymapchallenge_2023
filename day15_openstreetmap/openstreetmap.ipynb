# %% [markdown]
# * Data from https://opendata.dwd.de/weather/local_forecasts/swsmos/
# * overpass ai:
# ```
# [out:json][timeout:25];
# // gather results
# nwr["highway"="motorway"](48.46199462233164,7.525634765625001,51.53950234032649,13.3209228515625);
# // print results
# out geom;
# ```

# %%
using GeoJSON

# %%
roads=GeoJSON.read("roads.geojson")
# Out:
# FeatureCollection with 33002 Features

# %%
using GLMakie

# %%
using DataFrames

# %%
df=DataFrame(roads)
# Out:
# 33002×325 DataFrame
#    Row │ motor_vehicle  noise_barrier:right  nat_ref  surface:lanes  destinati ⋯
#        │ String?        String?              String?  String?        String?   ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ missing        missing              missing  missing        missing   ⋯
#      2 │ missing        missing              missing  missing        missing
#      3 │ missing        missing              missing  missing        missing
#      4 │ missing        missing              missing  missing        missing
#      5 │ missing        missing              missing  missing        missing   ⋯
#      6 │ missing        missing              missing  missing        missing
#      7 │ missing        missing              missing  missing        missing
#      8 │ missing        missing              missing  missing        missing
#    ⋮   │       ⋮                 ⋮              ⋮           ⋮                ⋮ ⋱
# ...

# %%
df.geometry
# Out:
# 33002-element Vector{Union{GeoJSON.LineString{2, Float32}, GeoJSON.Point{2, Float32}}}:
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 7 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 5 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 16 sub-geometries
#  ⋮
#  2D Point
#  2D Point
#  2D Point
#  2D Point
#  2D Point
#  2D Point
#  2D Point
#  2D Point
#  2D Point

# %%
roads_to_plot=GeoJSON.LineString{2,Float32}[]
# Out:
# GeoJSON.LineString{2, Float32}[]

# %%
for l in df.geometry
    if typeof(l)==GeoJSON.LineString{2,Float32}
        push!(roads_to_plot,l)
    end
end

# %%
roads_to_plot
# Out:
# 32985-element Vector{GeoJSON.LineString{2, Float32}}:
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 7 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 5 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 16 sub-geometries
#  ⋮
#  2D LineStringwith 2 sub-geometries
#  2D LineStringwith 12 sub-geometries
#  2D LineStringwith 2 sub-geometries
#  2D LineStringwith 4 sub-geometries
#  2D LineStringwith 3 sub-geometries
#  2D LineStringwith 5 sub-geometries
#  2D LineStringwith 6 sub-geometries
#  2D LineStringwith 2 sub-geometries
#  2D LineStringwith 3 sub-geometries

# %%
using GeoMakie

# %%
lines(GeoMakie.geo2basic.(roads_to_plot))

# %%
using CSV

# %%
roads_weather=CSV.File("swsmos_LATEST_opendata.csv")[2:end]|>DataFrame
# Out:
# ┌ Warning: thread = 1 warning: only found 1 / 16 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /home/tabea/.julia/packages/CSV/OnldF/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 1 / 16 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /home/tabea/.julia/packages/CSV/OnldF/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 1 / 16 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /home/tabea/.julia/packages/CSV/OnldF/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 1 / 16 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /home/tabea/.julia/packages/CSV/OnldF/src/file.jl:577
# ┌ Warning: thread = 1 warning: only found 1 / 16 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /home/tabea/.julia/packages/CSV/OnldF/src/file.jl:577
# 292584×16 DataFrame
# ...

# %%
ts=Union{Float64,Missing}[]
for station_forecast in eachrow(roads_weather)
    if station_forecast.TS=="---"
        push!(ts, missing)
    else
        push!(ts,parse(Float64,station_forecast.TS))
    end
end

# %%
roads_weather.TS_new=ts
# Out:
# 292584-element Vector{Union{Missing, Float64}}:
#  6.0
#  5.8
#  5.7
#  5.7
#  5.8
#  5.7
#  5.8
#  5.7
#  5.8
#  5.8
#  ⋮
#   missing
#   missing
#   missing
#   missing
#   missing
#   missing
#   missing
#   missing
#   missing

# %%
dropmissing!(roads_weather)
# Out:
# 202560×17 DataFrame
#     Row │ ID        Lat      Lon      YYYYMMDDHHmm  TL       TLSTA    RRL1c    ⋯
#         │ String15  Float64  Float64  Int64         Float64  String3  Float64  ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ A006      54.8892   8.9087  202311151900      5.8  0.4          1.7  ⋯
#       2 │ A006      54.8892   8.9087  202311152000      5.8  0.9          1.1
#       3 │ A006      54.8892   8.9087  202311152100      5.8  1.1          0.7
#       4 │ A006      54.8892   8.9087  202311152200      5.8  1.3          0.9
#       5 │ A006      54.8892   8.9087  202311152300      6.0  1.8          0.6  ⋯
#       6 │ A006      54.8892   8.9087  202311160000      5.7  1.5          0.4
#       7 │ A006      54.8892   8.9087  202311160100      6.1  1.1          0.2
#       8 │ A006      54.8892   8.9087  202311160200      5.7  1.4          0.2
#    ⋮    │    ⋮         ⋮        ⋮          ⋮           ⋮        ⋮        ⋮     ⋱
# ...

# %%
using Statistics

# %%
roads_weather_combi=combine(groupby(roads_weather,:ID),:TS_new=>mean,:Lat,:Lon)
# Out:
# 202560×4 DataFrame
#     Row │ ID        TS_new_mean  Lat      Lon
#         │ String15  Float64      Float64  Float64
# ────────┼─────────────────────────────────────────
#       1 │ A006          5.11198  54.8892   8.9087
#       2 │ A006          5.11198  54.8892   8.9087
#       3 │ A006          5.11198  54.8892   8.9087
#       4 │ A006          5.11198  54.8892   8.9087
#       5 │ A006          5.11198  54.8892   8.9087
#       6 │ A006          5.11198  54.8892   8.9087
#       7 │ A006          5.11198  54.8892   8.9087
#       8 │ A006          5.11198  54.8892   8.9087
#    ⋮    │    ⋮           ⋮          ⋮        ⋮
#  202554 │ V651          6.42455  48.1083  10.3558
#  202555 │ V651          6.42455  48.1083  10.3558
#  202556 │ V651          6.42455  48.1083  10.3558
#  202557 │ V651          6.42455  48.1083  10.3558
#  202558 │ V651          6.42455  48.1083  10.3558
#  202559 │ V651          6.42455  48.1083  10.3558
# ...

# %%
using ArchGDAL
layer=ArchGDAL.getlayer(ArchGDAL.read("../nuts5000_12-31.gk3.shape/nuts5000/NUTS5000_N1.shp"),0)
bounds=DataFrame(layer);
ArchGDAL.createcoordtrans(ArchGDAL.importURL("https://sg.geodatenzentrum.de/web_public/gdz/dokumentation/crs/gk3.prj"), ArchGDAL.importPROJ4("+proj=longlat +datum=WGS84 +no_defs +type=crs")) do transform
    for x in eachrow(bounds)
    ArchGDAL.transform!(x."", transform)
    end
end

# %%
fig =Figure()
Label(fig[1,1],text="Mean road surface temperature in the next 167 hours\n based on SWSMOS with motorways",fontsize=30)
ax=GeoAxis(fig[2,1],latlims=(48.5,51),lonlims=(6.5,12))
poly!(ax,GeoMakie.to_multipoly.(GeoMakie.geo2basic.(bounds."")),color=:transparent,strokecolor=:black,strokewidth=1)
s=scatter!(ax, roads_weather.Lon, roads_weather.Lat,color=roads_weather_combi.TS_new_mean,colormap=:berlin,colorrange=(3,9),highclip=cgrad(:berlin)[1.0])
lines!(ax,GeoMakie.geo2basic.(roads_to_plot),color=:green,strokewidth=2)
hidespines!(ax)
hidedecorations!(ax)
Colorbar(fig[2,2],s,label="Surface temperature in °C")
Label(fig[3,1],text="Data: © Deutscher Wetterdienst\nGeodata: © GeoBasis-DE / BKG (2023) and © OpenStreetMap and its contributors")
fig

# %%
save("openstreetmap.png",fig)
