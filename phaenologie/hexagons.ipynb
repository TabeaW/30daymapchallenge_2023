# %%
using DataFrames,CSV,Dates

# %%
df=CSV.File("PH_Beschreibung_Phaenologie_Stationen_Sofortmelder.txt",delim=";")|>DataFrame
# Out:
# 1208×13 DataFrame
#   Row │ Stations_id  Stationsname                                 geograph.Bre ⋯
#       │ Int64        String                                       Float64      ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │        7502  Kiel-Pries                                           54.4 ⋯
#     2 │        7505  L\xfcbeck-Schlutup                        …          53.9
#     3 │        7516  Gettorf                                              54.4
#     4 │        7525  Osdorf-Borghorst                                     54.4
#     5 │        7528  Rieseby                                              54.5 ⋯
#     6 │        7532  Norder-Hever-Koog                                    54.4
#     7 │        7533  Poppenb\xfcll                             …          54.3
#     8 │        7538  Schwartau, Bad                                       53.9
# ...
